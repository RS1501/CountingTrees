# %%
import sys
sys.path.append("../..")

# %%
from src.point_process import *
from src.utils import *
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
plt.rcParams.update({
    "text.usetex": True,          # Use LaTeX to render text
    "font.family": "serif",       # Match LaTeX serif font
    "font.size": 12
})

# %%
with open('../../parameters/superposition-c-01.json', 'r') as file:
    params = json.load(file)

# %%
Poisson1=PoissonProcess(params['poisson_1']['lam'])
points1=Poisson1.generate(params['poisson_1']['W'])
Poisson2=PoissonProcess(params['poisson_2']['lam'])
points2=Poisson2.generate(params['poisson_2']['W'])
Poisson3=PoissonProcess(params['poisson_3']['lam'])
points3=Poisson3.generate(params['poisson_3']['W'])

lam1, lam2, lam3 = params['poisson_1']['lam'], params['poisson_2']['lam'], params['poisson_3']['lam']

# %%
display_superposition([points1,points2,points3], title= f"Poisson({lam1: .2f}) + Poisson({lam2: .2f}) + Poisson({lam3: .2f})", labels=["$\lambda=50$","$\lambda=400$","$\lambda=100$"], path='../../img/superposition.eps')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_784284/3668256856.py:1: SyntaxWarning: invalid escape sequence '\l'
#   display_superposition([points1,points2,points3], title= f"Poisson({lam1: .2f}) + Poisson({lam2: .2f}) + Poisson({lam3: .2f})", labels=["$\lambda=50$","$\lambda=400$","$\lambda=100$"], path='../../img/superposition.eps')
# /tmp/ipykernel_784284/3668256856.py:1: SyntaxWarning: invalid escape sequence '\l'
#   display_superposition([points1,points2,points3], title= f"Poisson({lam1: .2f}) + Poisson({lam2: .2f}) + Poisson({lam3: .2f})", labels=["$\lambda=50$","$\lambda=400$","$\lambda=100$"], path='../../img/superposition.eps')
# ...
